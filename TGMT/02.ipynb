# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
my_dir = 'C:/Users/HI/Documents/TGMT'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (270, 180)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x180>
# (288, 180)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x180>
# (270, 180)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x180>
