# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/HI/Documents/TGMT/02.jpg'

# %%
img02 =  load_image(my_path)

# %%
display(img02)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x180>

# %%
region = (100, 75, 150, 160)
cropped_image = img02.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=50x85>

# %%
paste_position = (50, 50)
img02.paste(cropped_image, paste_position)
display(img02)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x180>
