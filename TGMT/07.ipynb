# %%
# !pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
my_path = 'C:/Users/HI/Documents/TGMT/02.jpg'
img02 = Image.open(my_path)
plt.imshow(img02)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 34, 30, 25]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='green')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='green') # Màu sắc
plt.title('Ví dụ về biểu đồ') # Title
plt.show() # Hiển thị

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.plot(x, y, color='red')  # Thay đổi màu thành đỏ
plt.title('Biểu đồ ví dụ với màu đỏ')  # Thêm tiêu đề
# Tắt hệ trục tọa độ
plt.axis('off')  # Tắt hệ trục tọa độ
plt.show()

# %%
img02 = Image.open(my_path)
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]

plt.imshow(img02)
plt.plot(x,y, 'ko-') 
plt.show()
