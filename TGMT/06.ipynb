# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/HI/Documents/TGMT/02.jpg'

# %%
img02 =  load_image(my_path)

# %%
display(img02)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x180>

# %%
gray_image = img02.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=270x180>

# %%
red_band, green_band, blue_band = img02.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=270x180>
# <PIL.Image.Image image mode=L size=270x180>
# <PIL.Image.Image image mode=L size=270x180>

# %%
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=270x180>
