# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/HI/Documents/TGMT/01.jpg'

# %%
img01 =  load_image(my_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x180>

# %%
print(img.size)
# Out:
# (270, 180)

# %%
new_size = (500,400)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400>

# %%
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x33>
