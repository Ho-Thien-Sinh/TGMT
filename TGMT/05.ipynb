# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/HI/Documents/TGMT/02.jpg'

# %%
img02 =  load_image(my_path)

# %%
display(img02)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x180>

# %%
rotated_image = img02.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=270x180>

# %%
transpose_image = img02.transpose(Image.Transpose.ROTATE_90)
display(transpose_image)
# Out:
# <PIL.Image.Image image mode=RGB size=180x270>
